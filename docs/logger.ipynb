# %%
from campbell.logger import FrameLogger
import matplotlib.pyplot as plt

# %%
cr = FrameLogger(url="http://cr3000",timeZone="Etc/GMT-1")

# %%
frame = cr.frameBackfill('dl:sonics_2d_10sec',300)

# %%
frame["Sonic2D_WSpd_23m"].plot()
# Out:
# <AxesSubplot:>
