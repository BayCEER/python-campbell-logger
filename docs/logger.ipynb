# %%
import campbell.logger as cp
import matplotlib.pyplot as plt

# %%
l = cp.FrameLogger(url="http://cr3000",timeZone="Etc/GMT-1")

# %%
frame = l.frameBackfill('dl:sonics_2d_10sec',300)

# %%
frame.head()
# Out:
# TIMESTAMP                             RECORD Sonic2D_WSpd_23m  \
# TS                                        RN              m/s
#                           Unnamed: 1_level_2              Smp
# 2020-09-10 11:57:20+01:00             190043              0.1
# 2020-09-10 11:57:30+01:00             190044              0.2
# 2020-09-10 11:57:40+01:00             190045              0.3
# 2020-09-10 11:57:50+01:00             190046              0.4
# 2020-09-10 11:58:00+01:00             190047              0.4
#
# TIMESTAMP                 Sonic2D_WDir_23m Sonic2D_x_23m Sonic2D_y_23m  \
# TS                                     deg           m/s           m/s
#                                        Smp           Smp           Smp
# 2020-09-10 11:57:20+01:00            239.6           0.0           0.0
# 2020-09-10 11:57:30+01:00              6.8          -0.2           0.0
# 2020-09-10 11:57:40+01:00              0.6          -0.3           0.0
# 2020-09-10 11:57:50+01:00            347.7          -0.4           0.1
# 2020-09-10 11:58:00+01:00            333.6          -0.3           0.2
#
# TIMESTAMP                 Sonic2D_SOS_23m Sonic2D_WSpd_13m Sonic2D_WDir_13m  \
# TS                                    mph              m/s              deg
#                                       Smp              Smp              Smp
# 2020-09-10 11:57:20+01:00           755.2              0.2            213.6
# 2020-09-10 11:57:30+01:00           755.1              0.2            255.0
# 2020-09-10 11:57:40+01:00           755.2              0.4            303.4
# 2020-09-10 11:57:50+01:00           755.1              0.3              6.5
# 2020-09-10 11:58:00+01:00           755.2              0.2              2.7
#
# TIMESTAMP                 Sonic2D_x_13m Sonic2D_y_13m Sonic2D_SOS_13m
# TS                                  m/s           m/s             mph
#                                     Smp           Smp             Smp
# 2020-09-10 11:57:20+01:00           0.2           0.1           755.8
# 2020-09-10 11:57:30+01:00           0.0           0.2           755.1
# 2020-09-10 11:57:40+01:00          -0.2           0.3           755.0
# 2020-09-10 11:57:50+01:00          -0.3           0.0           754.9
# 2020-09-10 11:58:00+01:00          -0.2           0.0           755.2

# %%
frame[['Sonic2D_WSpd_13m','Sonic2D_WSpd_23m']].plot()
# Out:
# <AxesSubplot:>
